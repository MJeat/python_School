# %% [markdown]
# #### 1. Linked List

# %%
# Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Singly Linked List implementation
class LinkedList:
    def __init__(self):
        self.head = None
    
    # Insert at the beginning
    def insert_first(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
    
    # Insert at the end
    def insert(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node
    
    # Delete a node
    def delete(self, data):
        if not self.head:
            return
        
        if self.head.data == data:
            self.head = self.head.next
            return
        
        current = self.head
        while current.next:
            if current.next.data == data:
                current.next = current.next.next
                return
            current = current.next
    
    # Display the linked list
    def display(self):
        elements = []
        current = self.head
        while current:
            elements.append(current.data)
            current = current.next
        return elements

# Example usage of Linked List
ll = LinkedList()
ll.insert(1)
ll.insert_first(5)
ll.insert_first(22)
ll.insert_first(3)
ll.insert_first(7)

print("Linked List:", ll.display())
ll.delete(22)
print("After deleting:", ll.display())
# Out:
# Linked List: [7, 3, 22, 5, 1]
# After deleting: [7, 3, 5, 1]

# %% [markdown]
# #### 2. Stack

# %%
# Stack implementation by leveraging Python list
class Stack:
    def __init__(self):
        self.items = []
    
    # Push == append()
    def push(self, item):
        self.items.append(item)
    
    # Pop == pop()
    def pop(self):
        if self.is_empty():
            return None
        return self.items.pop()
    
    # Peek at top element without removing
    def peek(self):
        if self.is_empty():
            return None
        return self.items[-1]
    
    # Check if stack is empty
    def is_empty(self):
        return not bool(self.items)
    
    # Get size of stack
    def size(self):
        return len(self.items)
    
    # Display stack contents
    def display(self):
        return self.items

# Example usage of Stack
stack = Stack()
print("Pushing elements: 1, 2, 3, 4")
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)

print("Stack contents:", stack.display())
print("Top element (peek):", stack.peek())
print("Popped element:", stack.pop())
print("Stack after pop:", stack.display())
print("Stack size:", stack.size())
# Out:
# Pushing elements: 1, 2, 3, 4
# Stack contents: [1, 2, 3, 4]
# Top element (peek): 4
# Popped element: 4
# Stack after pop: [1, 2, 3]
# Stack size: 3

# %% [markdown]
# #### 3. Queue

# %%
class Queue:
    def __init__(self):
        self.items = []
    
    # Enqueue == append()
    def enqueue(self, item):
        self.items.append(item)
    
    # Dequeue == removing from 0 index
    def dequeue(self):
        if self.is_empty():
            return None
        return self.items.pop(0)
    
    # Peek at front element
    def front(self):
        if self.is_empty():
            return None
        return self.items[0]
    
    # Peek at rear element
    def rear(self):
        if self.is_empty():
            return None
        return self.items[-1]
    
    # Check if queue is empty
    def is_empty(self):
        return not bool(self.items)
    
    # Get size of queue
    def size(self):
        return len(self.items)
    
    # Display queue contents
    def display(self):
        return self.items

# Example usage of Queue
queue = Queue()
print("Enqueuing customers: Alice, Bob, Charlie")
queue.enqueue("Alice")
queue.enqueue("Bob")
queue.enqueue("Charlie")

print("Queue contents:", queue.display())
print("Front customer:", queue.front())
print("Rear customer:", queue.rear())
print("Served customer:", queue.dequeue())
print("Queue after serving one customer:", queue.display())
