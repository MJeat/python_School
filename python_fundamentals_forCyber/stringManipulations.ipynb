# %%
print("Her name is 'Jane'")
print("Her name is \"Jane\"") # \ blackslash allows you to escape the special character inside a literal string
raw_string = r'C:\Users\Documen\'ts\examples!!@"".py'
print(raw_string)
text = 'Good morning. Welcome to "CYBR353" class. Have a great day!'
def count_space(text):
    count=0
    for char in text:
        if char == " ":
            count+=1
    return count
print(count_space(text))
# iterable, mutable, indexable
text1 = 'this is a phrase'
split_text1 = text1.split() # return you a list (defualt delimeter is space)
print(split_text1)
# list characteristic: iterable, indexable, mutatble
email = ['someone@gmail.com', 'nonone@yahoo.com', 'everyone@outlook.com']
username = []
emaildomain = []
for i in email:
    username.append(i.split('@')[0]) # ['someone']
    emaildomain.append(i.split('@')[1]) # ['gmail.com']
print("1. Split of username: ",username)
print("2. Split of email domain: ",emaildomain)
list1=[1,2,3,4,5]
odd=[i for i in list1 if i%2==0] #list comprehension # newlist = [value for value in mainlist if condition]
print(odd)
# traditional list, loop and condition
# odd=[]
# for i in list1:
# if i%2==0:
# odd.append(i)
# print(odd)
rawstring = r'https://www.aupp.edu.kh/school-of-digital-technologies/bachelor-of-science-in-cybersecurity/'
# string is iterable, indexable
listnew = rawstring.split('/')[2]
#0: https:
# /
#1: ''
#2: www.aupp.edu.kh
#.....
print(listnew)
phrase = "Welcome to CYBR 353"
splitPhrase = phrase.split()
print(splitPhrase)
jointPhrase = '$'.join(splitPhrase)
print(jointPhrase)
name = 'bob'
print("Hello {}".format(name))
