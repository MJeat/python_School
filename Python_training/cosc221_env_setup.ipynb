# %% [markdown]
# # COSC 221 - Computer Science B
# ## Environment Setup Verification Notebook
#
# **Welcome to COSC 221!** 🎉
#
# This notebook will help you verify that your Python environment is properly set up for this course. Run each cell in order to check your setup and install the necessary libraries.
#
# ---

# %% [markdown]
# ## 1. Python Version Check
#
# Let's first verify that you have Python 3.12+ installed as recommended in the syllabus.

# %%
import sys
import platform

print("🐍 Python Environment Information:")
print(f"Python Version: {sys.version}")
print(f"Python Version Info: {sys.version_info}")
print(f"Platform: {platform.platform()}")
print(f"Architecture: {platform.architecture()}")

# Check if Python version is 3.12 or higher
if sys.version_info >= (3, 12):
    print("\n✅ Great! You have Python 3.12+ as recommended.")
elif sys.version_info >= (3, 8):
    print("\n⚠️  You have a compatible Python version, but 3.12+ is recommended.")
else:
    print("\n❌ Warning: Python 3.8+ is required. Please upgrade your Python version.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import sys
#       2 import platform
#       4 print("🐍 Python Environment Information:")
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1466, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1508, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1309, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1946, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# ...

# %% [markdown]
# ## 2. Jupyter Notebook Verification
#
# If you can run this cell, congratulations! Your Jupyter Notebook is working correctly.

# %%
print("🎯 Jupyter Notebook Test:")
print("If you can see this message, your Jupyter Notebook is working correctly!")
print("✅ Jupyter Notebook setup: PASSED")

# Test basic Python functionality
test_list = [1, 2, 3, 4, 5]
test_sum = sum(test_list)
print(f"\n🧮 Basic Python test: sum({test_list}) = {test_sum}")
print("✅ Basic Python functionality: PASSED")

# %% [markdown]
# ## 3. Install Essential Libraries
#
# Now let's install the key libraries we'll need for the first half of the course (up to midterm).

# %%
# Install essential libraries using pip
print("📦 Installing essential libraries ...\n")

# !pip install numpy --upgrade  
# !pip install pandas --upgrade
# !pip install matplotlib --upgrade
# !pip install scikit-learn --upgrade
# !pip install seaborn --upgrade

print("\n🎉 Library installation completed!")
# Out:
# 📦 Installing essential libraries ...
#
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/12.8 MB 1.1 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/12.8 MB 671.3 kB/s eta 0:00:18
#    -- ------------------------------------- 0.8/12.8 MB 671.3 kB/s eta 0:00:18
#    -- ------------------------------------- 0.8/12.8 MB 671.3 kB/s eta 0:00:18
# ...

# %% [markdown]
# ## 4. Verify Library Installation
#
# Let's check that all the libraries were installed correctly and can be imported.

# %%
print("🔍 Verifying library installations:\n")

libraries_to_check = {
    'numpy': 'Numerical Python',
    'pandas': 'Data Analysis Library',
    'matplotlib': 'Plotting Library',
    'sklearn': 'Scikit-learn (Machine Learning)',
    'seaborn': 'Statistical Visualization',
}

successful_imports = 0
total_imports = len(libraries_to_check)

for library, description in libraries_to_check.items():
    try:
        if library == 'sklearn':
            import sklearn
            version = sklearn.__version__
        else:
            imported_lib = __import__(library)
            version = getattr(imported_lib, '__version__', 'Unknown')
        
        print(f"✅ {library:12} ({description}) - Version: {version}")
        successful_imports += 1
    except ImportError:
        print(f"❌ {library:12} ({description}) - Failed to import")

print(f"\n📊 Import Summary: {successful_imports}/{total_imports} libraries imported successfully")

if successful_imports == total_imports:
    print("🎉 All libraries imported successfully! You're ready for the course.")
else:
    print("⚠️  Some libraries failed to import. Please check the error messages above.")
# Out:
# 🔍 Verifying library installations:
#
# ✅ numpy        (Numerical Python) - Version: 2.3.2
# ✅ pandas       (Data Analysis Library) - Version: 2.3.1
# ✅ matplotlib   (Plotting Library) - Version: 3.10.5
# ✅ sklearn      (Scikit-learn (Machine Learning)) - Version: 1.7.1
# ✅ seaborn      (Statistical Visualization) - Version: 0.13.2
#
# 📊 Import Summary: 5/5 libraries imported successfully
# 🎉 All libraries imported successfully! You're ready for the course.

# %% [markdown]
# ## 5. Final Setup Summary
#
# Congratulations! If all the cells above ran successfully, your environment is properly configured.
